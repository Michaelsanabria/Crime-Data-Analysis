# %%
import pandas as pd

# %%
data = pd.read_csv('Crime_Incidents_in_the_Last_30_Days.csv')

# Display the first few rows of the dataframe
data.head()
# Display the column information
data.info()
# Display summary statistics
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1831 entries, 0 to 1830
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   X                     1831 non-null   float64
#  1   Y                     1831 non-null   float64
#  2   CCN                   1831 non-null   int64
#  3   REPORT_DAT            1831 non-null   object
#  4   SHIFT                 1831 non-null   object
#  5   METHOD                1831 non-null   object
#  6   OFFENSE               1831 non-null   object
#  7   BLOCK                 1831 non-null   object
#  8   XBLOCK                1831 non-null   float64
#  9   YBLOCK                1831 non-null   float64
#  10  WARD                  1831 non-null   int64
#  11  ANC                   1831 non-null   object
#  12  DISTRICT              1823 non-null   float64
#  13  PSA                   1823 non-null   float64
#  14  NEIGHBORHOOD_CLUSTER  1831 non-null   object
# ...
